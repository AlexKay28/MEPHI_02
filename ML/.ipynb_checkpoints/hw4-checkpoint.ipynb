# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn import linear_model
from sklearn.cluster import KMeans
from sklearn import model_selection
from sklearn import metrics 
from pandas import DataFrame
from matplotlib import pylab as plt

from copy import copy
import random
import sys
import time

# %%
# Загружаем набор данных Ирисы:
iris = datasets.load_iris()

iris_frame = DataFrame(iris.data)
iris_frame.columns = iris.feature_names
iris_frame['target'] = iris.target
iris_frame['name'] = iris_frame.target.apply(lambda x : iris.target_names[x])
iris_frame
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target       name
# 0         0     setosa
# 1         0     setosa
# 2         0     setosa
# 3         0     setosa
# 4         0     setosa
# ..      ...        ...
# 145       2  virginica
# 146       2  virginica
# 147       2  virginica
# 148       2  virginica
# 149       2  virginica
#
# [150 rows x 6 columns]

# %%
iris_frame['petal_area'] = 0.0
for k in range(len(iris_frame['petal length (cm)'])):
    iris_frame['petal_area'][k] = iris_frame['petal length (cm)'][k] * iris_frame['petal width (cm)'][k]


s1 = iris_frame[iris_frame['target'] == 2]
s1 = s1.replace(2, 1)
s2 = iris_frame[iris_frame['target'] == 1]
s2 = s2.replace(1, 0)
binary = pd.concat([s1, s2])

X_train, X_test, y_train, y_test = model_selection.train_test_split(binary[['petal length (cm)','petal_area']], 
                                                                                    binary[['target']], 
                                                                                    test_size = 0.3, 
                                                                                    random_state = 0)
from matplotlib.colors import ListedColormap
colors = ListedColormap(['red', 'green','blue'])
fig = plt.figure(1, figsize=(15, 5))
plt.scatter(X_test['petal length (cm)'], X_test['petal_area'], c=y_test.iloc[:,0], cmap=colors)
plt.ylabel('petal_area')
plt.xlabel('petal length (cm)')
plt.show()
binary
# Out:
# /home/alexkay/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# ..                 ...               ...                ...               ...
# 95                 5.7               3.0                4.2               1.2
# 96                 5.7               2.9                4.2               1.3
# 97                 6.2               2.9                4.3               1.3
# 98                 5.1               2.5                3.0               1.1
# 99                 5.7               2.8                4.1               1.3
#
#      target        name  petal_area
# 100       1   virginica       15.00
# 101       1   virginica        9.69
# 102       1   virginica       12.39
# 103       1   virginica       10.08
# 104       1   virginica       12.76
# ..      ...         ...         ...
# 95        0  versicolor        5.04
# 96        0  versicolor        5.46
# 97        0  versicolor        5.59
# 98        0  versicolor        3.30
# 99        0  versicolor        5.33
#
# [100 rows x 7 columns]

# %% [raw]
# def penalty_2D(real, pred, cl):
#     if real > pred:
#         cl_pred = 1
#         return 0 if cl_pred == cl else abs(pred-real)
#     elif real == pred:
#         return 0
#     else:
#         cl_pred = 0
#         return 0 if cl_pred == cl else abs(pred-real)
#
# def Job(X, Y, w):
#     err = 0
#     for i in range(len(X)):
#         real = X[i][1]
#         pred = X[i][0]*w[1] + w[0]
#         cl = Y[i][0]
#         err += penalty_2D(real, pred, cl)
#     return err
#
# def Stohastic_GradDesc(X, Y, rate=0.01, h=0.0000001, eps=10e-8, dim=2):
#     iterations = 0
#     w = [random.randint(0, 20) for i in range(dim)]
#     was = Job(X, Y, w)
#     print('was = ', was)
#
#     w_new = [0, 0]
#
#     while 1:
#         if iterations%2 == 0:
#             print(f"Iteration {iterations}", end="\r")
#         iterations += 1
#
#         i = random.randint(0, len(w)-1)
#
#         w1 = copy(w)
#         w1[i] = w1[i] - h
#         w_new[i] = (w[i] - rate * (1/h)*(Job(X,Y, w) - Job(X,Y,w1)))
#         w1 = copy(w)
#
#         w = copy(w_new)
#         became = Job(X,Y, w_new)
#         delt = abs(became - was)
#         if delt > eps: was = became
#         else: break
#         if iterations > (10**5):
#             print('Something is going wrong... bruh')
#             break
#
#     print('Err became:\t',round(became,4))
#
#     delt = abs(became - was)
#     print('final delt:\t', round(delt,4))
#     print('iterations:\t', iterations)
#     return w
#
# w = Stohastic_GradDesc(np.array(X_train), np.array(y_train))
# print('weights is : ', w)
#
# from matplotlib.colors import ListedColormap
# x = np.linspace(3,7)
#
# colors = ListedColormap(['red', 'green','blue'])
# fig = plt.figure(1, figsize=(15, 5))
# plt.scatter(X_test['petal length (cm)'], X_test['petal_area'], c=y_test.iloc[:,0], cmap=colors)
# plt.ylabel('petal_area')
# plt.xlabel('petal length (cm)')
# plt.plot(x, [(w[1]*x-w[0]) for x in x])
# plt.show()

# %%
class SGDClassifier:
    def __init__(self, rate=0.01, h=0.0000001, eps=10e-8, dim=2, threshold=10e5):
        self.rate = rate
        self.h = h
        self.eps = eps
        self.dim = dim
        self.threshold = threshold
        #self.w = 'No weight'
    
    def penalty_2D(self, real, pred, cl):
        """ 
        Penalty for mistakes 
        """
        if real > pred:
            cl_pred = 1
            return 0 if cl_pred == cl else abs(pred-real)
        elif real == pred:
            return 0
        else:
            cl_pred = 0
            return 0 if cl_pred == cl else abs(pred-real)
    
    def Job(self, X, Y, w):
        err = 0
        for i in range(len(Y)):
            real = X[i][1]
            pred = X[i][0]*w[1] + w[0]
            cl = Y[i][0]
            err += self.penalty_2D(real, pred, cl)
        return err
    
    def SGD(self, X, Y):
        """
        SGD realisation
        """
        iterations = 0
        w = [random.randint(0, 20) for i in range(self.dim)]
        was = self.Job(X, Y, w)
        print('Err in the beginning = ', was)
        
        eps = self.eps
        h = self.h
        rate = self.rate
        
        w_new = [0, 0]

        while 1:
            if iterations%2 == 0:
                print(f"Iteration {iterations}", end="\r")
            iterations += 1

            i = random.randint(0, len(w)-1)

            w1 = copy(w)
            w1[i] = w1[i] - h
            w_new[i] = (w[i] - rate * (1/h)*(self.Job(X,Y, w) - self.Job(X,Y,w1)))
            w1 = copy(w)

            w = copy(w_new)
            became = self.Job(X,Y, w_new)
            delt = abs(became - was)
            if delt > eps: was = became
            else: break
            if iterations > (self.threshold):
                print('Something is going wrong... bruh')
                break

        print('Err became:\t',round(became,4))

        delt = abs(became - was)
        print('final delt:\t', round(delt,4))
        print('iterations:\t', iterations)
        return w
    
    def fit(self, X, Y):
        X_train = np.array(X)
        y_train = np.array(Y)
        w = self.SGD(X_train, y_train)
        print('weights is : ', w)
        self.w = w
        return self.w
    
    def evaluate(self):
        from matplotlib.colors import ListedColormap
        x = np.linspace(3,7)
        
        try:
            w = self.w
        except AttributeError:
            print('Action sequence error!')
            print('Please, make you sure model was fitted already')
            print('(Fit your model and repeat this part)')

        
        colors = ListedColormap(['red', 'green','blue'])
        fig = plt.figure(1, figsize=(15, 5))
        plt.scatter(X_test['petal length (cm)'], X_test['petal_area'], c=y_test.iloc[:,0], cmap=colors)
        plt.ylabel('petal_area')
        plt.xlabel('petal length (cm)')
        plt.plot(x, [(w[1]*x-w[0]) for x in x])
        plt.show()

        
if __name__ == "__main__":
    model = SGDClassifier()
    model.fit(X_train, y_test)
    model.evaluate()
# Out:
# Err in the beginning =  20.969999999999995
# Err became:	 13.4432
# final delt:	 0.0
# iterations:	 15
# weights is :  [0.2499999990135393, 1.7480000003899931]
